# %% [markdown]
# # Ground Motion Displacement RMS vs Time
#
# *an example simple tutorial for getting seismic data, computing the power spectral densities, extracting the RMS and plotting*
#
# Required:
#
# - python
# - obspy (and its dependencies)
# - pandas
# - jupyter
# - notebook
#
# this should be easy to set up in a conda env: ``conda create -c conda-forge -n covid python=3.7 obspy pandas jupyter notebook``
#
# Author: Thomas Lecocq @seismotom, Fred Massin @fmassin, Claudio Satriano @claudiodsf

# %% [markdown]
# ## Step 1: imports

# %%
import datetime
import os
from glob import glob

import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42  # to edit text in Illustrator
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import matplotlib.patheffects as pe
import numpy as np
import pandas as pd
import seismosocialdistancing

from obspy import UTCDateTime, read
from obspy.clients.fdsn import Client
from obspy.signal import PPSD

# %% [markdown]
# ## Step 2: Define Start/End dates and Seismic Channel
#
# You'll have to make sure the seed_id you request is indeed available from the ``data_provider``

# %%
start = UTCDateTime("2020-03-13")
end = UTCDateTime() # means "now"

network = "BE"
station = "UCC"
location = ""
channel = "HHZ"
dataset = "example"

data_provider = "ODC"
logo = None #plt.imread('https://upload.wikimedia.org/wikipedia/commons/thumb/4/44/Logo_SED_2014.png/220px-Logo_SED_2014.png')
bans = {"2020-03-10":'Groups >1000 banned', 
        "2020-03-17":'All gathering banned'}

# %% [markdown]
# ## Step 3: Download the seismic waveform data
#
# This step is coded so that only the last day is redownloaded if the daily files are present on the disk.
#
# The request gets the target day +- 30 minutes to avoid having gaps at the end of each day (need 1 window covering midnight).

# %%
datelist = pd.date_range(start.datetime, end.datetime, freq="D")
c = Client(data_provider)

nslc = "{}.{}.{}.{}".format(network, station, location, channel)
# make sure that wildcard characters are not in nslc
nslc = nslc.replace("*", "").replace("?", "")
for day in datelist:
    datestr = day.strftime("%Y-%m-%d")
    fn = "{}_{}_{}.mseed".format(dataset, datestr, nslc)
    print(fn)
    if day != datelist[-1] and os.path.isfile(fn):
        continue
    else:
        st = c.get_waveforms(network, station, location, channel,
                             UTCDateTime(day)-1801, UTCDateTime(day)+86400+1801, attach_response=True)
        print(st)
        st.write(fn)
resp = c.get_stations(UTCDateTime(day), network=network, station=station, location=location,
                      channel=channel, level="response")
print(resp)
# Out:
# example_2020-03-13_BE.UCC..HHZ.mseed
# 1 Trace(s) in Stream:
# BE.UCC..HHZ | 2020-03-12T23:29:55.590000Z - 2020-03-14T00:30:04.900000Z | 100.0 Hz, 9000932 samples
# example_2020-03-14_BE.UCC..HHZ.mseed
# 1 Trace(s) in Stream:
# BE.UCC..HHZ | 2020-03-13T23:29:55.830000Z - 2020-03-15T00:30:02.060000Z | 100.0 Hz, 9000624 samples
# example_2020-03-15_BE.UCC..HHZ.mseed
# 1 Trace(s) in Stream:
# BE.UCC..HHZ | 2020-03-14T23:29:57.670000Z - 2020-03-16T00:30:01.760000Z | 100.0 Hz, 9000410 samples
# example_2020-03-16_BE.UCC..HHZ.mseed
# 1 Trace(s) in Stream:
# BE.UCC..HHZ | 2020-03-15T23:29:56.830000Z - 2020-03-17T00:30:02.680000Z | 100.0 Hz, 9000586 samples
# example_2020-03-17_BE.UCC..HHZ.mseed
# 1 Trace(s) in Stream:
# BE.UCC..HHZ | 2020-03-16T23:29:57.730000Z - 2020-03-18T00:30:03.100000Z | 100.0 Hz, 9000538 samples
# example_2020-03-18_BE.UCC..HHZ.mseed
# 1 Trace(s) in Stream:
# BE.UCC..HHZ | 2020-03-17T23:29:58.250000Z - 2020-03-19T00:30:02.820000Z | 100.0 Hz, 9000458 samples
# example_2020-03-19_BE.UCC..HHZ.mseed
# 1 Trace(s) in Stream:
# BE.UCC..HHZ | 2020-03-18T23:29:57.950000Z - 2020-03-20T00:30:03.140000Z | 100.0 Hz, 9000520 samples
# example_2020-03-20_BE.UCC..HHZ.mseed
# 1 Trace(s) in Stream:
# BE.UCC..HHZ | 2020-03-19T23:29:58.210000Z - 2020-03-21T00:30:01.520000Z | 100.0 Hz, 9000332 samples
# example_2020-03-21_BE.UCC..HHZ.mseed
# 1 Trace(s) in Stream:
# BE.UCC..HHZ | 2020-03-20T23:29:56.630000Z - 2020-03-22T00:30:01.620000Z | 100.0 Hz, 9000500 samples
# example_2020-03-22_BE.UCC..HHZ.mseed
# 1 Trace(s) in Stream:
# BE.UCC..HHZ | 2020-03-21T23:29:56.730000Z - 2020-03-23T00:30:03.220000Z | 100.0 Hz, 9000650 samples
# example_2020-03-23_BE.UCC..HHZ.mseed
# 1 Trace(s) in Stream:
# BE.UCC..HHZ | 2020-03-22T23:29:58.310000Z - 2020-03-24T00:30:01.300000Z | 100.0 Hz, 9000300 samples
# example_2020-03-24_BE.UCC..HHZ.mseed
# 1 Trace(s) in Stream:
# BE.UCC..HHZ | 2020-03-23T23:29:56.330000Z - 2020-03-25T00:30:02.380000Z | 100.0 Hz, 9000606 samples
# example_2020-03-25_BE.UCC..HHZ.mseed
# 1 Trace(s) in Stream:
# BE.UCC..HHZ | 2020-03-24T23:29:57.570000Z - 2020-03-26T00:30:01.680000Z | 100.0 Hz, 9000412 samples
# example_2020-03-26_BE.UCC..HHZ.mseed
# 1 Trace(s) in Stream:
# BE.UCC..HHZ | 2020-03-25T23:29:57.110000Z - 2020-03-27T00:30:01.220000Z | 100.0 Hz, 9000412 samples
# example_2020-03-27_BE.UCC..HHZ.mseed
# 1 Trace(s) in Stream:
# BE.UCC..HHZ | 2020-03-26T23:29:56.690000Z - 2020-03-28T00:30:01.060000Z | 100.0 Hz, 9000438 samples
# example_2020-03-28_BE.UCC..HHZ.mseed
# 1 Trace(s) in Stream:
# BE.UCC..HHZ | 2020-03-27T23:29:58.710000Z - 2020-03-29T00:30:03.400000Z | 100.0 Hz, 9000470 samples
# example_2020-03-29_BE.UCC..HHZ.mseed
# 1 Trace(s) in Stream:
# BE.UCC..HHZ | 2020-03-28T23:29:58.770000Z - 2020-03-30T00:30:02.400000Z | 100.0 Hz, 9000364 samples
# example_2020-03-30_BE.UCC..HHZ.mseed
# 1 Trace(s) in Stream:
# BE.UCC..HHZ | 2020-03-29T23:29:57.410000Z - 2020-03-31T00:30:01.400000Z | 100.0 Hz, 9000400 samples
# example_2020-03-31_BE.UCC..HHZ.mseed
# 1 Trace(s) in Stream:
# BE.UCC..HHZ | 2020-03-30T23:29:56.410000Z - 2020-04-01T00:30:02.120000Z | 100.0 Hz, 9000572 samples
# example_2020-04-01_BE.UCC..HHZ.mseed
# 1 Trace(s) in Stream:
# BE.UCC..HHZ | 2020-03-31T23:29:57.130000Z - 2020-04-02T00:30:03.460000Z | 100.0 Hz, 9000634 samples
# example_2020-04-02_BE.UCC..HHZ.mseed
# 1 Trace(s) in Stream:
# BE.UCC..HHZ | 2020-04-01T23:29:58.470000Z - 2020-04-03T00:30:02.040000Z | 100.0 Hz, 9000358 samples
# example_2020-04-03_BE.UCC..HHZ.mseed
# 1 Trace(s) in Stream:
# BE.UCC..HHZ | 2020-04-02T23:29:57.050000Z - 2020-04-04T00:30:04.020000Z | 100.0 Hz, 9000698 samples
# example_2020-04-04_BE.UCC..HHZ.mseed
# 1 Trace(s) in Stream:
# BE.UCC..HHZ | 2020-04-03T23:29:54.910000Z - 2020-04-05T00:30:01.700000Z | 100.0 Hz, 9000680 samples
# example_2020-04-05_BE.UCC..HHZ.mseed
# 1 Trace(s) in Stream:
# BE.UCC..HHZ | 2020-04-04T23:29:56.710000Z - 2020-04-06T00:30:04.920000Z | 100.0 Hz, 9000822 samples
# example_2020-04-06_BE.UCC..HHZ.mseed
# 1 Trace(s) in Stream:
# BE.UCC..HHZ | 2020-04-05T23:29:55.810000Z - 2020-04-07T00:30:02.840000Z | 100.0 Hz, 9000704 samples
# example_2020-04-07_BE.UCC..HHZ.mseed
# 1 Trace(s) in Stream:
# BE.UCC..HHZ | 2020-04-06T23:29:57.850000Z - 2020-04-08T00:30:04.080000Z | 100.0 Hz, 9000624 samples
# example_2020-04-08_BE.UCC..HHZ.mseed
# 1 Trace(s) in Stream:
# BE.UCC..HHZ | 2020-04-07T23:29:54.970000Z - 2020-04-09T00:30:02.940000Z | 100.0 Hz, 9000798 samples
# example_2020-04-09_BE.UCC..HHZ.mseed
# 1 Trace(s) in Stream:
# BE.UCC..HHZ | 2020-04-08T23:29:57.950000Z - 2020-04-10T00:30:02.520000Z | 100.0 Hz, 9000458 samples
# example_2020-04-10_BE.UCC..HHZ.mseed
# 1 Trace(s) in Stream:
# BE.UCC..HHZ | 2020-04-09T23:29:57.530000Z - 2020-04-11T00:30:03.880000Z | 100.0 Hz, 9000636 samples
# example_2020-04-11_BE.UCC..HHZ.mseed
# 1 Trace(s) in Stream:
# BE.UCC..HHZ | 2020-04-10T23:29:58.890000Z - 2020-04-12T00:30:01.440000Z | 100.0 Hz, 9000256 samples
# example_2020-04-12_BE.UCC..HHZ.mseed
# 3 Trace(s) in Stream:
# BE.UCC..HHZ | 2020-04-11T23:29:56.450000Z - 2020-04-12T20:29:20.440000Z | 100.0 Hz, 7556400 samples
# BE.UCC..HHZ | 2020-04-12T20:29:22.660000Z - 2020-04-12T20:52:52.410000Z | 100.0 Hz, 140976 samples
# BE.UCC..HHZ | 2020-04-12T20:52:52.630000Z - 2020-04-13T00:30:01.400000Z | 100.0 Hz, 1302878 samples
# example_2020-04-13_BE.UCC..HHZ.mseed
# 1 Trace(s) in Stream:
# BE.UCC..HHZ | 2020-04-12T23:29:56.410000Z - 2020-04-13T18:52:34.580000Z | 100.0 Hz, 6975818 samples
# Inventory created at 2020-04-13T18:55:39.461325Z
# 	Sending institution: SeisComP3 (ODC)
# 	Contains:
# 		Networks (1):
# 			BE
# 		Stations (1):
# 			BE.UCC (Uccle, Brussels, Belgium)
# 		Channels (1):
# 			BE.UCC..HHZ

# %% [markdown]
# ## Step 4: Compute PPSDs using custom parameters
#
# These parameters are set to allow the PSDs to be "nervous", not as smooth as the default PQLX ones.

# %%
for day in datelist:
    datestr = day.strftime("%Y-%m-%d")
    fn_in = "{}_{}_{}.mseed".format(dataset, datestr, nslc)
    if day == datelist[-1] :
        continue
    stall = read(fn_in)
    for mseedid in list(set([tr.id for tr in stall])):
        fn_out = "{}_{}_{}.npz".format(dataset, datestr, mseedid)
        if os.path.isfile(fn_out):
            print("%s done already."%fn_out)
            continue
        st = stall.select(id=mseedid)
        st.attach_response(resp)
        ppsd = PPSD(st[0].stats, metadata=resp,
                    ppsd_length=1800, overlap=0.5,
                    period_smoothing_width_octaves=0.025,
                    period_step_octaves=0.0125,
                    period_limits=(0.008, 50),
                    db_bins=(-200, 20, 0.25))
        ppsd.add(st)
        ppsd.save_npz(fn_out[:-4])
        print(st)
        del st, ppsd
    del stall
# Out:
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:996: RuntimeWarning: Mean of empty slice.
#   smoothed_psd.append(specs.mean())
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/numpy/core/_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# 1 Trace(s) in Stream:
# BE.UCC..HHZ | 2020-03-12T23:29:55.590000Z - 2020-03-14T00:30:04.900000Z | 100.0 Hz, 9000932 samples
# 1 Trace(s) in Stream:
# BE.UCC..HHZ | 2020-03-13T23:29:55.830000Z - 2020-03-15T00:30:02.060000Z | 100.0 Hz, 9000624 samples
# 1 Trace(s) in Stream:
# BE.UCC..HHZ | 2020-03-14T23:29:57.670000Z - 2020-03-16T00:30:01.760000Z | 100.0 Hz, 9000410 samples
# 1 Trace(s) in Stream:
# BE.UCC..HHZ | 2020-03-15T23:29:56.830000Z - 2020-03-17T00:30:02.680000Z | 100.0 Hz, 9000586 samples
# 1 Trace(s) in Stream:
# BE.UCC..HHZ | 2020-03-16T23:29:57.730000Z - 2020-03-18T00:30:03.100000Z | 100.0 Hz, 9000538 samples
# 1 Trace(s) in Stream:
# BE.UCC..HHZ | 2020-03-17T23:29:58.250000Z - 2020-03-19T00:30:02.820000Z | 100.0 Hz, 9000458 samples
# 1 Trace(s) in Stream:
# BE.UCC..HHZ | 2020-03-18T23:29:57.950000Z - 2020-03-20T00:30:03.140000Z | 100.0 Hz, 9000520 samples
# 1 Trace(s) in Stream:
# BE.UCC..HHZ | 2020-03-19T23:29:58.210000Z - 2020-03-21T00:30:01.520000Z | 100.0 Hz, 9000332 samples
# 1 Trace(s) in Stream:
# BE.UCC..HHZ | 2020-03-20T23:29:56.630000Z - 2020-03-22T00:30:01.620000Z | 100.0 Hz, 9000500 samples
# 1 Trace(s) in Stream:
# BE.UCC..HHZ | 2020-03-21T23:29:56.730000Z - 2020-03-23T00:30:03.220000Z | 100.0 Hz, 9000650 samples
# 1 Trace(s) in Stream:
# BE.UCC..HHZ | 2020-03-22T23:29:58.310000Z - 2020-03-24T00:30:01.300000Z | 100.0 Hz, 9000300 samples
# 1 Trace(s) in Stream:
# BE.UCC..HHZ | 2020-03-23T23:29:56.330000Z - 2020-03-25T00:30:02.380000Z | 100.0 Hz, 9000606 samples
# 1 Trace(s) in Stream:
# BE.UCC..HHZ | 2020-03-24T23:29:57.570000Z - 2020-03-26T00:30:01.680000Z | 100.0 Hz, 9000412 samples
# 1 Trace(s) in Stream:
# BE.UCC..HHZ | 2020-03-25T23:29:57.110000Z - 2020-03-27T00:30:01.220000Z | 100.0 Hz, 9000412 samples
# 1 Trace(s) in Stream:
# BE.UCC..HHZ | 2020-03-26T23:29:56.690000Z - 2020-03-28T00:30:01.060000Z | 100.0 Hz, 9000438 samples
# 1 Trace(s) in Stream:
# BE.UCC..HHZ | 2020-03-27T23:29:58.710000Z - 2020-03-29T00:30:03.400000Z | 100.0 Hz, 9000470 samples
# 1 Trace(s) in Stream:
# BE.UCC..HHZ | 2020-03-28T23:29:58.770000Z - 2020-03-30T00:30:02.400000Z | 100.0 Hz, 9000364 samples
# 1 Trace(s) in Stream:
# BE.UCC..HHZ | 2020-03-29T23:29:57.410000Z - 2020-03-31T00:30:01.400000Z | 100.0 Hz, 9000400 samples
# 1 Trace(s) in Stream:
# BE.UCC..HHZ | 2020-03-30T23:29:56.410000Z - 2020-04-01T00:30:02.120000Z | 100.0 Hz, 9000572 samples
# 1 Trace(s) in Stream:
# BE.UCC..HHZ | 2020-03-31T23:29:57.130000Z - 2020-04-02T00:30:03.460000Z | 100.0 Hz, 9000634 samples
# 1 Trace(s) in Stream:
# BE.UCC..HHZ | 2020-04-01T23:29:58.470000Z - 2020-04-03T00:30:02.040000Z | 100.0 Hz, 9000358 samples
# 1 Trace(s) in Stream:
# BE.UCC..HHZ | 2020-04-02T23:29:57.050000Z - 2020-04-04T00:30:04.020000Z | 100.0 Hz, 9000698 samples
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-d74b78366aec> in <module>
#      18                     period_limits=(0.008, 50),
#      19                     db_bins=(-200, 20, 0.25))
# ---> 20         ppsd.add(st)
#      21         ppsd.save_npz(fn_out[:-4])
#      22         print(st)
#
# ~/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py in add(self, stream, verbose)
#     886                     # XXX not good, should be working in place somehow
#     887                     # XXX how to do it with the padding, though?
# --> 888                     success = self.__process(slice)
#     889                     if success:
#     890                         if verbose:
#
# ~/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py in __process(self, tr)
#     958             # determine instrument response from metadata
#     959             try:
# --> 960                 resp = self._get_response(tr)
#     961             except Exception as e:
#     962                 msg = ("Error getting response from provided metadata:\n"
#
# ~/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py in _get_response(self, tr)
#    1250         # but that makes the object non-picklable
#    1251         if isinstance(self.metadata, Inventory):
# -> 1252             return self._get_response_from_inventory(tr)
#    1253         elif isinstance(self.metadata, Parser):
#    1254             return self._get_response_from_parser(tr)
#
# ~/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py in _get_response_from_inventory(self, tr)
#    1265         response = inventory.get_response(self.id, tr.stats.starttime)
#    1266         resp, _ = response.get_evalresp_response(
# -> 1267             t_samp=self.delta, nfft=self.nfft, output="VEL")
#    1268         return resp
#    1269
#
# ~/anaconda3/lib/python3.5/site-packages/obspy/core/inventory/response.py in get_evalresp_response(self, t_samp, nfft, output, start_stage, end_stage)
#    1426         fy = 1 / (t_samp * 2.0)
#    1427         # start at zero to get zero for offset/ DC of fft
# -> 1428         freqs = np.linspace(0, fy, nfft // 2 + 1).astype(np.float64)
#    1429
#    1430         response = self.get_evalresp_response_for_frequencies(
#
# ~/anaconda3/lib/python3.5/site-packages/numpy/core/function_base.py in linspace(start, stop, num, endpoint, retstep, dtype)
#     131         else:
#     132             if _mult_inplace:
# --> 133                 y *= step
#     134             else:
#     135                 y = y * step
#
# KeyboardInterrupt:

# %% [markdown]
# ## Step 5: Reload daily PSDs from the disk and create a single PPSD object:

# %%
ppsds = {}
for day in datelist:
    datestr = day.strftime("%Y-%m-%d")
    fn_pattern = "{}_{}_*.npz".format(dataset, datestr)
    for fn in glob(fn_pattern):
        mseedid = fn.replace(".npz", "").split("_")[-1]
        if mseedid not in ppsds:
            ppsds[mseedid] = PPSD.load_npz(fn)#, allow_pickle=True)
        else:
            ppsds[mseedid].add_npz(fn)#, allow_pickle=True)
# Out:
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file 'example_2020-03-14_BE.UCC..HHZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file 'example_2020-03-15_BE.UCC..HHZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file 'example_2020-03-16_BE.UCC..HHZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file 'example_2020-03-17_BE.UCC..HHZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file 'example_2020-03-18_BE.UCC..HHZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file 'example_2020-03-19_BE.UCC..HHZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file 'example_2020-03-20_BE.UCC..HHZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file 'example_2020-03-21_BE.UCC..HHZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file 'example_2020-03-22_BE.UCC..HHZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file 'example_2020-03-23_BE.UCC..HHZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file 'example_2020-03-24_BE.UCC..HHZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file 'example_2020-03-25_BE.UCC..HHZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file 'example_2020-03-26_BE.UCC..HHZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file 'example_2020-03-27_BE.UCC..HHZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file 'example_2020-03-28_BE.UCC..HHZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file 'example_2020-03-29_BE.UCC..HHZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file 'example_2020-03-30_BE.UCC..HHZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file 'example_2020-03-31_BE.UCC..HHZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file 'example_2020-04-01_BE.UCC..HHZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file 'example_2020-04-02_BE.UCC..HHZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file 'example_2020-04-03_BE.UCC..HHZ.npz' (time ranges already covered).
#   warnings.warn(msg)

# %% [markdown]
# ## Step 6: Standard plots:

# %%
[ppsd.plot(max_percentage=10) for mseedid, ppsd in ppsds.items()]
[ppsd.plot_temporal(0.10) for mseedid, ppsd in ppsds.items()]
[ppsd.plot_spectrogram(clim=(-160,-100)) for mseedid, ppsd in ppsds.items()]

# %% [markdown]
# ## Step 7: Process PSDs to extract the RMS(displacement)
#
# This can be done for multiple filters at once (``freqs`` below):

# %%
# Define frequency bands of interest:
freqs = [(0.1,1.0),(1.0,20.0),(4.0,14.0),(4.0,20.0)]


def rms(s, f):
    # Parseval: the RMS in time domain is the sqrt of the integral of the power spectrum
    return np.sqrt(np.trapz(s, f))

displacement_RMS = {}
for mseedid, ppsd in ppsds.items():
    per = ppsd.period_bin_centers
    displacement_RMS[mseedid] = []
    for psd in ppsd.psd_values:
        RMS = {}
        for fmin, fmax in freqs:
            ix = np.where((per>=1.0/fmax) & (per<=1.0/fmin))

            # acceleration power spectrum in Hz
            spec = psd.copy()[ix][::-1]
            f = 1.0/per.copy()[ix][::-1]

            # remove NaNs from the list
            valid = np.where(np.isfinite(spec))[0]
            spec = spec[valid]
            f = f[valid]

            w2f = (2.0 * np.pi * f)

            # The acceleration amplitude spectrum (dB to Power! = divide by 10 and not 20!)
            amp = 10.0**(spec/10.) 

            # velocity spectrum (divide by omega**2)
            vamp = amp / w2f**2

            # displacement spectrum (divide by omega**2)
            damp =  vamp / w2f**2

            RMS["%.1f-%.1f"%(fmin, fmax)] = rms(damp, f)

        displacement_RMS[mseedid].append(RMS)
        index = pd.DatetimeIndex([d.datetime for d in ppsd.times_processed])
    displacement_RMS[mseedid] = pd.DataFrame(displacement_RMS[mseedid], index=index)
    print(mseedid," rms done.")
# Out:
# BE.UCC..HHZ  rms done.

# %% [markdown]
# ## Step 8: Custom plot for a single frequency band:

# %%
band = "4.0-14.0"

for mseedid in list(set(k[:-1] for k in displacement_RMS)):
    net, sta, loc, chan = mseedid.split('.')
    fig = plt.figure(figsize=(12,6))
    if logo is not None:
        fig.figimage(logo, 40, 40, alpha=.4, zorder=1)
    
    data={}
    for o in 'ZEN':
        if mseedid+o not in displacement_RMS:
            continue
        data[chan+o] = displacement_RMS[mseedid+o][band]
        main = chan+o
        
    if len(data.keys())>1:
        data[chan+'*'] = data[main].copy() # for the sum
        main = chan+'*'
        for i,t in enumerate(data[main].index):        
            data[main][i] = 0
            for o in data:
                if o == main:
                    continue
                if len(data[o].index)-1<i:
                    break
                if abs(data[o].index[i].timestamp()-data[main].index[i].timestamp())<60:
                    data[main][i] += data[o][i]**2
            data[main][i] = data[main][i]**.5
    
    plt.plot(data[main].index, data[main], label = main)
    
    for o in data:
        rs = data[o].copy().between_time("6:00", "16:00")
        rs = rs.resample("1D" ).median().tshift(12, "H")
        plt.plot(rs.index, rs, 
                 label="$\overline{%s}$ (6h-16h)"%o)

    

    # Get normal business days and set their background color to green
    db = pd.bdate_range(start.datetime, end.datetime)
    for dbi in db:
        plt.axvspan(dbi, dbi+datetime.timedelta(days=1),
                    facecolor='lightgreen', edgecolor="none",
                    alpha=0.2, zorder=-10)

    scale = 1e9
    plt.ylim(0,np.percentile(data[main],95)*1.5)
    ticks = ticker.FuncFormatter(lambda x, pos: "{0:g}".format(x*scale))
    plt.gca().yaxis.set_major_formatter(ticks)
    plt.ylabel("Displacement (nm)")

    plt.title('Seismic Noise for {}.{}.{}.{} - Filter: [{}] Hz'.format(
        net, sta, loc, main, band))
    plt.xlim(data[main].index.min(), data[main].index.max())
    fig.autofmt_xdate()
    plt.grid(True, zorder=-1)
    plt.gca().set_axisbelow(True)    
    for iban,ban in enumerate(bans.keys()):
        plt.axvline(UTCDateTime(ban).datetime,
                    color='r', 
                    linewidth=2,
                    linestyle=['-', '--', '-.', ':'][iban],
                    path_effects=[pe.withStroke(linewidth=4, foreground="k")],
                    zorder=-9,
                    label=bans[ban])
    plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
    plt.show()
    fig.savefig(mseedid+".pdf",bbox_inches='tight')
    fig.savefig(mseedid+".png",bbox_inches='tight')
    
    ax = seismosocialdistancing.hourmap(data[main], 
                                        bans=bans, 
                                        scale = scale)
    ax.set_title('Seismic Noise for {}.{}.{}.{} - Filter: [{}] Hz'.format(
        net, sta, loc, main, band))
    fig.savefig(channelcode+"-hour.pdf",bbox_inches='tight')
    fig.savefig(channelcode+"-hour.png",bbox_inches='tight')
# Out:
# <img src="data:image/png;base64,..." width="1200">
